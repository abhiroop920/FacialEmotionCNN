# %% [markdown]
# # 1: UNDERSTAND THE PROBLEM STATEMENT AND BUSINESS CASE

# %% [markdown]
# ### In this project we create a deep learning model based on CNN and Residual Blocks to predict facial Expressions.
# ### We acquired the data set from kaggle.
# ### Our dataset consists five different emotions.They are anger,disgust,sad,happy,surprise
# ### Our dataset has two attributes, they are
# ###        1)Emotion(Integer)
# ###        2)Pixel(string)
# ### The size of our data set is 24568

# %% [markdown]
# # 2: IMPORT LIBRARIES AND DATASETS

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\sangu\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: gast==0.3.3 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (3.15.7)
# Requirement already satisfied: absl-py~=0.10 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\sangu\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\sangu\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.28.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sangu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sangu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sangu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sangu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sangu\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sangu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sangu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\sangu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sangu\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sangu\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# '2.4.1'

# %%
import cv2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import pickle
from tensorflow.python.keras import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K

# %%
# read the csv files
emotion_df = pd.read_csv('emotion.csv')

# %%
emotion_df
# Out:
#        emotion                                             pixels
# 0            0  70 80 82 72 58 58 60 63 54 58 60 48 89 115 121...
# 1            0  151 150 147 155 148 133 111 140 170 174 182 15...
# 2            2  24 32 36 30 32 23 19 20 30 41 21 22 32 34 21 1...
# 3            2  20 17 19 21 25 38 42 42 46 54 56 62 63 66 82 1...
# 4            3  77 78 79 79 78 75 60 55 47 48 58 73 77 79 57 5...
# ...        ...                                                ...
# 24563        3  0 39 81 80 104 97 51 64 68 46 41 67 53 68 70 5...
# 24564        0  181 177 176 156 178 144 136 132 122 107 131 16...
# 24565        3  178 174 172 173 181 188 191 194 196 199 200 20...
# 24566        0  17 17 16 23 28 22 19 17 25 26 20 24 31 19 27 9...
# 24567        3  30 28 28 29 31 30 42 68 79 81 77 67 67 71 63 6...
#
# [24568 rows x 2 columns]

# %%
emotion_df['emotion'][2]
# Out:
# 2

# %%
emotion_df['pixels'] = emotion_df[' pixels'] # String format

# %%
emotion_df['pixels'][2] # String format
# Out:
# '24 32 36 30 32 23 19 20 30 41 21 22 32 34 21 19 43 52 13 26 40 59 65 12 20 63 99 98 98 111 75 62 41 73 118 140 192 186 187 188 190 190 187 182 176 173 172 173 25 34 29 35 29 26 20 23 19 31 22 21 20 31 26 17 34 75 37 18 38 80 85 25 38 26 34 97 94 76 86 95 70 39 98 129 185 188 188 189 190 190 188 182 176 173 172 173 26 29 25 35 25 30 20 21 16 28 34 26 15 17 19 22 29 62 64 47 45 76 76 78 65 82 12 14 56 56 72 74 66 65 86 129 172 190 187 189 190 190 187 182 177 172 172 174 26 33 32 31 25 33 26 21 16 16 37 27 14 15 12 17 31 38 40 58 73 59 35 82 68 72 43 22 33 52 51 66 71 57 71 121 160 191 188 189 190 190 187 184 178 173 173 174 29 40 29 29 32 32 28 26 19 13 23 34 17 18 14 15 26 25 21 40 82 44 29 34 36 32 36 59 55 38 46 64 71 62 60 107 137 191 189 190 190 190 188 184 178 175 173 175 33 39 25 33 37 33 25 30 20 18 18 23 20 22 20 17 33 20 18 25 37 31 22 29 28 24 29 38 67 38 35 75 68 66 58 89 110 179 191 189 189 190 187 184 179 175 173 174 32 41 32 31 39 33 26 34 27 23 28 30 21 24 29 22 26 23 21 22 33 28 28 26 28 23 27 21 61 53 24 72 78 64 54 84 94 155 195 189 191 190 188 184 179 174 172 173 28 46 40 29 42 34 31 39 37 30 33 33 28 23 30 31 24 19 17 18 27 25 27 23 25 24 23 13 40 69 29 45 74 74 59 88 88 145 196 188 191 191 188 183 178 174 172 174 27 44 42 35 42 34 39 40 41 37 33 33 34 31 32 35 32 19 19 18 16 17 22 21 23 25 22 14 30 74 36 32 62 75 59 89 94 139 194 188 191 191 187 184 179 174 173 174 28 38 38 42 41 36 51 44 37 40 35 33 29 38 38 43 39 28 23 19 22 24 26 27 26 29 21 17 37 75 31 32 49 55 57 102 108 138 193 189 191 192 189 184 180 176 174 174 29 33 30 34 41 39 46 45 37 38 38 34 28 39 41 44 36 37 28 29 32 34 35 34 33 33 27 23 39 72 28 22 44 70 82 127 100 137 194 189 190 189 188 185 181 176 174 176 29 32 28 24 40 35 35 30 30 31 38 29 31 37 30 34 30 41 52 57 58 56 53 45 50 40 46 24 30 60 27 64 120 130 141 139 85 149 194 187 189 188 187 185 181 177 175 176 34 24 33 27 26 27 27 21 24 28 34 27 33 30 23 26 27 52 91 125 125 119 100 89 88 84 66 24 48 57 89 137 155 159 175 155 105 173 193 189 189 189 187 185 181 177 175 176 33 74 146 130 75 24 23 20 20 23 26 24 27 24 24 31 60 118 156 158 156 155 141 135 131 108 42 68 73 97 140 146 164 178 186 191 156 185 189 189 188 188 186 184 180 177 175 176 45 121 121 162 155 61 17 22 21 23 22 21 21 24 29 62 127 165 170 163 166 159 144 128 103 53 67 99 90 129 148 153 175 195 201 180 174 188 187 188 188 187 186 184 180 177 176 176 64 105 116 165 150 143 45 17 19 23 23 22 23 25 52 122 166 171 172 174 169 160 152 128 91 97 124 119 123 144 151 157 179 177 143 154 184 187 188 189 189 187 186 183 180 177 176 176 125 93 150 159 133 143 106 33 49 27 24 25 23 44 120 166 170 165 159 142 132 120 117 119 129 131 128 132 135 142 146 158 144 94 131 185 185 186 187 188 189 187 185 183 179 176 175 176 201 82 161 117 85 143 158 109 119 67 21 39 86 132 168 173 171 167 161 148 134 123 102 89 100 102 97 108 124 131 152 118 75 138 131 170 185 186 187 188 189 187 185 183 178 175 175 175 225 80 130 122 84 146 145 162 159 129 31 94 168 172 170 170 167 162 143 117 112 77 50 47 65 100 127 135 129 137 157 56 73 168 181 180 185 187 188 189 189 187 184 181 178 174 173 175 217 80 78 165 127 109 119 169 173 163 108 138 172 168 172 171 165 158 140 101 65 43 44 56 38 95 141 160 146 166 142 62 116 171 198 180 185 186 188 188 187 186 183 181 177 174 173 175 194 64 36 127 178 168 113 132 172 166 153 158 170 170 171 173 171 168 165 161 139 96 72 69 53 111 163 170 155 163 187 143 162 205 204 180 186 187 188 188 187 185 184 181 177 174 173 175 144 55 54 51 146 177 158 154 173 169 160 165 168 161 145 136 164 172 167 153 137 132 117 90 85 134 168 176 162 160 212 197 188 208 203 182 188 187 189 189 187 186 184 181 177 174 173 175 127 79 91 61 47 157 160 166 161 164 160 154 148 153 146 105 131 154 146 145 128 108 118 104 114 127 156 166 156 163 207 190 185 207 194 181 183 185 180 180 184 181 183 180 176 174 172 174 136 102 122 138 60 73 130 139 138 153 137 142 122 135 140 114 89 144 117 108 116 110 110 103 97 107 142 145 139 151 202 157 159 189  ...

# %%
# function to convert pixel values in string format to array format
def string2array(x):
  return np.array(x.split(' ')).reshape(48, 48, 1).astype('float32')

# %%
emotion_df['pixels'] = emotion_df['pixels'].apply(lambda x: string2array(x))

# %%
emotion_df['pixels'][2].shape
# Out:
# (48, 48, 1)

# %%
emotion_df['pixels'][2]
# Out:
# array([[[ 24.],
#         [ 32.],
#         [ 36.],
#         ...,
#         [173.],
#         [172.],
#         [173.]],
#
#        [[ 25.],
#         [ 34.],
#         [ 29.],
#         ...,
#         [173.],
#         [172.],
#         [173.]],
#
#        [[ 26.],
#         [ 29.],
#         [ 25.],
#         ...,
#         [172.],
#         [172.],
#         [174.]],
#
#        ...,
#
#        [[159.],
#         [185.],
#         [157.],
#         ...,
#         [157.],
#         [156.],
#         [153.]],
#
#        [[136.],
#         [157.],
#         [187.],
#         ...,
#         [152.],
#         [152.],
#         [150.]],
#
#        [[145.],
#         [130.],
#         [161.],
#         ...,
#         [142.],
#         [143.],
#         [142.]]], dtype=float32)

# %%
# checking for the presence of null values in the data frame
emotion_df.isnull().sum()
# Out:
# emotion    0
#  pixels    0
# pixels     0
# dtype: int64

# %%
label_to_text = {0:'anger', 1:'disgust', 2:'sad', 3:'happiness', 4: 'surprise'}

# %% [markdown]
#  # 3: PERFORM DATA VISUALIZATION

# %%
emotions = [0,1,2,3,4]

for i in emotions:
  data = emotion_df[emotion_df['emotion'] == i][:1]
  img = data['pixels'].item()
  img = img.reshape(48,48)
  plt.figure()
  plt.title(label_to_text[i])
  plt.imshow(img, cmap= 'gray')

# %%
plt.figure(figsize = (10, 10))
sns.barplot(x = emotion_df.emotion.value_counts().index, y = emotion_df.emotion.value_counts() )
plt.title('Number of images per emotion')
# Out:
# Text(0.5, 1.0, 'Number of images per emotion')

# %% [markdown]
#  # 4: PERFORM DATA AUGMENTATION

# %%
emotion_df['pixels'][10]
# Out:
# array([[[219.],
#         [192.],
#         [179.],
#         ...,
#         [184.],
#         [225.],
#         [150.]],
#
#        [[197.],
#         [179.],
#         [ 63.],
#         ...,
#         [212.],
#         [206.],
#         [133.]],
#
#        [[169.],
#         [166.],
#         [ 65.],
#         ...,
#         [234.],
#         [169.],
#         [115.]],
#
#        ...,
#
#        [[ 21.],
#         [ 21.],
#         [ 36.],
#         ...,
#         [ 26.],
#         [ 33.],
#         [ 79.]],
#
#        [[ 31.],
#         [ 30.],
#         [ 44.],
#         ...,
#         [ 31.],
#         [ 69.],
#         [ 62.]],
#
#        [[ 31.],
#         [ 34.],
#         [ 53.],
#         ...,
#         [ 57.],
#         [ 39.],
#         [ 40.]]], dtype=float32)

# %%
emotion_df['emotion'][10]
# Out:
# 2

# %%
X = emotion_df['pixels']
X.shape
# Out:
# (24568,)

# %%
# split the dataframe to features and labels
X = emotion_df['pixels']
y = pd.get_dummies(emotion_df['emotion'])

X = np.stack(X, axis = 0)
X = X.reshape(24568, 48, 48, 1)

print(X.shape, y.shape)
# Out:
# (24568, 48, 48, 1) (24568, 5)

# %%
X.shape
# Out:
# (24568, 48, 48, 1)

# %%
y.shape
# Out:
# (24568, 5)

# %%
X
# Out:
# array([[[[ 70.],
#          [ 80.],
#          [ 82.],
#          ...,
#          [ 52.],
#          [ 43.],
#          [ 41.]],
#
#         [[ 65.],
#          [ 61.],
#          [ 58.],
#          ...,
#          [ 56.],
#          [ 52.],
#          [ 44.]],
#
#         [[ 50.],
#          [ 43.],
#          [ 54.],
#          ...,
#          [ 49.],
#          [ 56.],
#          [ 47.]],
#
#         ...,
#
#         [[ 91.],
#          [ 65.],
#          [ 42.],
#          ...,
#          [ 72.],
#          [ 56.],
#          [ 43.]],
#
#         [[ 77.],
#          [ 82.],
#          [ 79.],
#          ...,
#          [105.],
#          [ 70.],
#          [ 46.]],
#
#         [[ 77.],
#          [ 72.],
#          [ 84.],
#          ...,
#          [106.],
#          [109.],
#          [ 82.]]],
#
#
#        [[[151.],
#          [150.],
#          [147.],
#          ...,
#          [129.],
#          [140.],
#          [120.]],
#
#         [[151.],
#          [149.],
#          [149.],
#          ...,
#          [122.],
#          [141.],
#          [137.]],
#
#         [[151.],
#          [151.],
#          [156.],
#          ...,
#          [109.],
#          [123.],
#          [146.]],
#
#         ...,
#
#         [[188.],
#          [188.],
#          [121.],
#          ...,
#          [185.],
#          [185.],
#          [186.]],
#
#         [[188.],
#          [187.],
#          [196.],
#          ...,
#          [186.],
#          [182.],
#          [187.]],
#
#         [[186.],
#          [184.],
#          [185.],
#          ...,
#          [193.],
#          [183.],
#          [184.]]],
#
#
#        [[[ 24.],
#          [ 32.],
#          [ 36.],
#          ...,
#          [173.],
#          [172.],
#          [173.]],
#
#         [[ 25.],
#          [ 34.],
#          [ 29.],
#          ...,
#          [173.],
#          [172.],
#          [173.]],
#
#         [[ 26.],
#          [ 29.],
#          [ 25.],
#          ...,
#          [172.],
#          [172.],
#          [174.]],
#
#         ...,
#
#         [[159.],
#          [185.],
#          [157.],
#          ...,
#          [157.],
#          [156.],
#          [153.]],
#
#         [[136.],
#          [157.],
#          [187.],
#          ...,
#          [152.],
#          [152.],
#          [150.]],
#
#         [[145.],
#          [130.],
#          [161.],
#          ...,
#          [142.],
#          [143.],
#          [142.]]],
#
#
#        ...,
#
#
#        [[[178.],
#          [174.],
#          [172.],
#          ...,
#          [ 78.],
#          [ 41.],
#          [ 57.]],
#
#         [[181.],
#          [178.],
#          [178.],
#          ...,
#          [126.],
#          [ 63.],
#          [ 64.]],
#
#         [[181.],
#          [176.],
#          [176.],
#          ...,
#          [177.],
#          [145.],
#          [ 82.]],
#
#         ...,
#
#         [[193.],
#          [191.],
#          [187.],
#          ...,
#          [  1.],
#          [  1.],
#          [  0.]],
#
#         [[193.],
#          [192.],
#          [191.],
#          ...,
#          [  0.],
#          [  0.],
#          [  0.]],
#
#         [[194.],
#          [191.],
#          [192.],
#          ...,
#          [  0.],
#          [  0.],
#          [  0.]]],
#
#
#        [[[ 17.],
#          [ 17.],
#          [ 16.],
#          ...,
#          [ 83.],
#          [114.],
#          [245.]],
#
#         [[ 18.],
#          [ 17.],
#          [ 16.],
#          ...,
#          [104.],
#          [136.],
#          [253.]],
#
#         [[ 19.],
#          [ 16.],
#          [ 17.],
#          ...,
#          [128.],
#          [152.],
#          [255.]],
#
#         ...,
#
#         [[  4.],
#          [ 21.],
#          [ 46.],
#          ...,
#          [186.],
#          [180.],
#          [187.]],
#
#         [[  5.],
#          [ 17.],
#          [ 41.],
#          ...,
#          [177.],
#          [172.],
#          [176.]],
#
#         [[ 20.],
#          [ 15.],
#          [ 22.],
#          ...,
#          [154.],
#          [133.],
#          [113.]]],
#
#
#        [[[ 30.],
#          [ 28.],
#          [ 28.],
#          ...,
#          [ 60.],
#          [ 50.],
#          [ 44.]],
#
#         [[ 30.],
#          [ 27.],
#          [ 28.],
#          ...,
#          [ 64.],
#          [ 52.],
#          [ 40.]],
#
#         [[ 31.],
#          [ 28.],
#          [ 30.],
#          ...,
#          [ 61.],
#          [ 54.],
#          [ 37.]],
#
#         ...,
#
#         [[104.],
#          [109.],
#          [110.],
#          ...,
#          [ 35.],
#          [ 30.],
#          [ 30.]],
#
#         [[102.],
#          [105.],
#          [108.],
#          ...,
#          [ 35.],
#          [ 31.],
#          [ 29.]],
#
#         [[ 93.],
#          [ 96.],
#          [100.],
#          ...,
#          [ 35.],
#          [ 30.],
#          [ 28.]]]], dtype=float32)

# %%
X = np.array(X)
y = np.array(y)

# %%
# spliting the dataframe in to train,test and validation data frames

from sklearn.model_selection import train_test_split

X_train, X_Test, y_train, y_Test = train_test_split(X,y,test_size = 0.1, shuffle = True)
X_val, X_Test, y_val, y_Test = train_test_split(X_Test,y_Test, test_size = 0.5, shuffle = True)

# %%
print(X_val.shape, y_val.shape)
# Out:
# (1228, 48, 48, 1) (1228, 5)

# %%
print(X_Test.shape, y_Test.shape)
# Out:
# (1229, 48, 48, 1) (1229, 5)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (22111, 48, 48, 1) (22111, 5)

# %%
# image pre-processing
# normalization
X_train = X_train/255
X_val   = X_val /255
X_Test  = X_Test/255

# %%
train_datagen = ImageDataGenerator(
rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode = "nearest"
)

# %% [markdown]
#  # 5: UNDERSTAND THE INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS AND RESNETS

# %% [markdown]
# ![img2-1.png](attachment:img2-1.png)

# %% [markdown]
# ![img3-1.png](attachment:img3-1.png)

# %% [markdown]
# ![Screenshot%202021-06-18%20201226.png](attachment:Screenshot%202021-06-18%20201226.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # 6: BUILD AND TRAIN DEEP LEARNING MODEL FOR FACIAL EXPRESSION CLASSIFICATION

# %%
def res_block(X, filter, stage):

  # Convolutional_block
  X_copy = X

  f1 , f2, f3 = filter

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPool2D((2,2))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)


  # Short path
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPool2D((2,2))(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 1
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 2
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = (48, 48, 1)

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3, 3))(X_input)

# 1 - stage
X = Conv2D(64, (7, 7), strides= (2, 2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3, 3), strides= (2, 2))(X)

# 2 - stage
X = res_block(X, filter= [64, 64, 256], stage= 2)

# 3 - stage
X = res_block(X, filter= [128, 128, 512], stage= 3)

# Average Pooling
X = AveragePooling2D((2, 2), name = 'Averagea_Pooling')(X)

# Final layer
X = Flatten()(X)
X = Dense(5, activation = 'softmax', name = 'Dense_final', kernel_initializer= glorot_uniform(seed=0))(X)

model_emotion = Model( inputs= X_input, outputs = X, name = 'Resnet18')

model_emotion.summary()
# Out:
# Model: "Resnet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 54, 54, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 24, 24, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 24, 24, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 24, 24, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 11, 11, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# res_2_conv_a (Conv2D)           (None, 11, 11, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 5, 64)     0           res_2_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_a (BatchNormalization (None, 5, 5, 64)     256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 5, 5, 64)     0           bn_2_conv_a[0][0]
# __________________________________________________________________________________________________
# res_2_conv_b (Conv2D)           (None, 5, 5, 64)     36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_b (BatchNormalization (None, 5, 5, 64)     256         res_2_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 5, 5, 64)     0           bn_2_conv_b[0][0]
# __________________________________________________________________________________________________
# res_2_conv_copy (Conv2D)        (None, 11, 11, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# res_2_conv_c (Conv2D)           (None, 5, 5, 256)    16640       activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 256)    0           res_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_c (BatchNormalization (None, 5, 5, 256)    1024        res_2_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_copy (BatchNormalizat (None, 5, 5, 256)    1024        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 5, 5, 256)    0           bn_2_conv_c[0][0]
#                                                                  bn_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 5, 5, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_a (Conv2D)     (None, 5, 5, 64)     16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_a (BatchNormali (None, 5, 5, 64)     256         res_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 5, 5, 64)     0           bn_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_b (Conv2D)     (None, 5, 5, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_b (BatchNormali (None, 5, 5, 64)     256         res_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 5, 5, 64)     0           bn_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_c (Conv2D)     (None, 5, 5, 256)    16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_c (BatchNormali (None, 5, 5, 256)    1024        res_2_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 5, 5, 256)    0           bn_2_identity_1_c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 5, 5, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_a (Conv2D)     (None, 5, 5, 64)     16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_a (BatchNormali (None, 5, 5, 64)     256         res_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 5, 5, 64)     0           bn_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_b (Conv2D)     (None, 5, 5, 64)     36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_b (BatchNormali (None, 5, 5, 64)     256         res_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 64)     0           bn_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_c (Conv2D)     (None, 5, 5, 256)    16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_c (BatchNormali (None, 5, 5, 256)    1024        res_2_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 5, 256)    0           bn_2_identity_2_c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 5, 5, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res_3_conv_a (Conv2D)           (None, 5, 5, 128)    32896       activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 128)    0           res_3_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_a (BatchNormalization (None, 2, 2, 128)    512         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 2, 2, 128)    0           bn_3_conv_a[0][0]
# __________________________________________________________________________________________________
# res_3_conv_b (Conv2D)           (None, 2, 2, 128)    147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_b (BatchNormalization (None, 2, 2, 128)    512         res_3_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 2, 2, 128)    0           bn_3_conv_b[0][0]
# __________________________________________________________________________________________________
# res_3_conv_copy (Conv2D)        (None, 5, 5, 512)    131584      activation_9[0][0]
# __________________________________________________________________________________________________
# res_3_conv_c (Conv2D)           (None, 2, 2, 512)    66048       activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 512)    0           res_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_c (BatchNormalization (None, 2, 2, 512)    2048        res_3_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_copy (BatchNormalizat (None, 2, 2, 512)    2048        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 2, 2, 512)    0           bn_3_conv_c[0][0]
#                                                                  bn_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2, 2, 512)    0           add_3[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_a (Conv2D)     (None, 2, 2, 128)    65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_a (BatchNormali (None, 2, 2, 128)    512         res_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2, 2, 128)    0           bn_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_b (Conv2D)     (None, 2, 2, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_b (BatchNormali (None, 2, 2, 128)    512         res_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 128)    0           bn_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_c (Conv2D)     (None, 2, 2, 512)    66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_c (BatchNormali (None, 2, 2, 512)    2048        res_3_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 512)    0           bn_3_identity_1_c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_a (Conv2D)     (None, 2, 2, 128)    65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_a (BatchNormali (None, 2, 2, 128)    512         res_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 128)    0           bn_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_b (Conv2D)     (None, 2, 2, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_b (BatchNormali (None, 2, 2, 128)    512         res_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 128)    0           bn_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_c (Conv2D)     (None, 2, 2, 512)    66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_c (BatchNormali (None, 2, 2, 512)    2048        res_3_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 2, 2, 512)    0           bn_3_identity_2_c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# Averagea_Pooling (AveragePoolin (None, 1, 1, 512)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           Averagea_Pooling[0][0]
# __________________________________________________________________________________________________
# Dense_final (Dense)             (None, 5)            2565        flatten[0][0]
# ==================================================================================================
# Total params: 1,174,021
# Trainable params: 1,165,445
# Non-trainable params: 8,576
# __________________________________________________________________________________________________

# %%
# train the network
model_emotion.compile(optimizer = "Adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
# using early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 20)

# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath = "FacialExpression_weights.hdf5", verbose = 1, save_best_only=True)

# %%
history = model_emotion.fit(train_datagen.flow(X_train, y_train, batch_size=64),
	validation_data=(X_val, y_val), steps_per_epoch=len(X_train) // 64,
	epochs= 50, callbacks=[checkpointer, earlystopping])
# Out:
# Epoch 1/50
# 345/345 [==============================] - 81s 222ms/step - loss: 1.6675 - accuracy: 0.3716 - val_loss: 1.3702 - val_accuracy: 0.4080
#
# Epoch 00001: val_loss improved from inf to 1.37021, saving model to FacialExpression_weights.hdf5
# Epoch 2/50
# 345/345 [==============================] - 75s 218ms/step - loss: 1.1960 - accuracy: 0.5210 - val_loss: 1.3564 - val_accuracy: 0.4642
#
# Epoch 00002: val_loss improved from 1.37021 to 1.35643, saving model to FacialExpression_weights.hdf5
# Epoch 3/50
# 345/345 [==============================] - 76s 220ms/step - loss: 1.0769 - accuracy: 0.5703 - val_loss: 1.4493 - val_accuracy: 0.3420
#
# Epoch 00003: val_loss did not improve from 1.35643
# Epoch 4/50
# 345/345 [==============================] - 75s 216ms/step - loss: 0.9890 - accuracy: 0.6034 - val_loss: 1.3122 - val_accuracy: 0.4544
#
# Epoch 00004: val_loss improved from 1.35643 to 1.31221, saving model to FacialExpression_weights.hdf5
# Epoch 5/50
# 345/345 [==============================] - 73s 213ms/step - loss: 0.9224 - accuracy: 0.6313 - val_loss: 1.2039 - val_accuracy: 0.5171
#
# Epoch 00005: val_loss improved from 1.31221 to 1.20391, saving model to FacialExpression_weights.hdf5
# Epoch 6/50
# 345/345 [==============================] - 73s 211ms/step - loss: 0.8769 - accuracy: 0.6517 - val_loss: 1.0345 - val_accuracy: 0.5814
#
# Epoch 00006: val_loss improved from 1.20391 to 1.03450, saving model to FacialExpression_weights.hdf5
# Epoch 7/50
# 345/345 [==============================] - 97s 282ms/step - loss: 0.8501 - accuracy: 0.6649 - val_loss: 0.9620 - val_accuracy: 0.6270
#
# Epoch 00007: val_loss improved from 1.03450 to 0.96196, saving model to FacialExpression_weights.hdf5
# Epoch 8/50
# 345/345 [==============================] - 85s 247ms/step - loss: 0.7928 - accuracy: 0.6862 - val_loss: 0.9265 - val_accuracy: 0.6246
#
# Epoch 00008: val_loss improved from 0.96196 to 0.92646, saving model to FacialExpression_weights.hdf5
# Epoch 9/50
# 345/345 [==============================] - 85s 245ms/step - loss: 0.7892 - accuracy: 0.6892 - val_loss: 0.8377 - val_accuracy: 0.6669
#
# Epoch 00009: val_loss improved from 0.92646 to 0.83769, saving model to FacialExpression_weights.hdf5
# Epoch 10/50
# 345/345 [==============================] - 85s 248ms/step - loss: 0.7561 - accuracy: 0.7098 - val_loss: 0.8950 - val_accuracy: 0.6319
#
# Epoch 00010: val_loss did not improve from 0.83769
# Epoch 11/50
# 345/345 [==============================] - 84s 244ms/step - loss: 0.7477 - accuracy: 0.7064 - val_loss: 0.9475 - val_accuracy: 0.6205
#
# Epoch 00011: val_loss did not improve from 0.83769
# Epoch 12/50
# 345/345 [==============================] - 83s 242ms/step - loss: 0.7168 - accuracy: 0.7187 - val_loss: 0.9772 - val_accuracy: 0.6368
#
# Epoch 00012: val_loss did not improve from 0.83769
# Epoch 13/50
# 345/345 [==============================] - 88s 256ms/step - loss: 0.6943 - accuracy: 0.7330 - val_loss: 0.7840 - val_accuracy: 0.6857
#
# Epoch 00013: val_loss improved from 0.83769 to 0.78403, saving model to FacialExpression_weights.hdf5
# Epoch 14/50
# 345/345 [==============================] - 90s 260ms/step - loss: 0.6867 - accuracy: 0.7298 - val_loss: 2.0732 - val_accuracy: 0.4072
#
# Epoch 00014: val_loss did not improve from 0.78403
# Epoch 15/50
# 345/345 [==============================] - 86s 249ms/step - loss: 0.6773 - accuracy: 0.7402 - val_loss: 0.9341 - val_accuracy: 0.6197
#
# Epoch 00015: val_loss did not improve from 0.78403
# Epoch 16/50
# 345/345 [==============================] - 86s 249ms/step - loss: 0.6582 - accuracy: 0.7437 - val_loss: 0.7705 - val_accuracy: 0.7044
#
# Epoch 00016: val_loss improved from 0.78403 to 0.77049, saving model to FacialExpression_weights.hdf5
# Epoch 17/50
# 345/345 [==============================] - 91s 262ms/step - loss: 0.6287 - accuracy: 0.7564 - val_loss: 0.7614 - val_accuracy: 0.7060
#
# Epoch 00017: val_loss improved from 0.77049 to 0.76142, saving model to FacialExpression_weights.hdf5
# Epoch 18/50
# 345/345 [==============================] - 86s 250ms/step - loss: 0.6318 - accuracy: 0.7523 - val_loss: 0.8852 - val_accuracy: 0.6653
#
# Epoch 00018: val_loss did not improve from 0.76142
# Epoch 19/50
# 345/345 [==============================] - 90s 262ms/step - loss: 0.6092 - accuracy: 0.7652 - val_loss: 0.8169 - val_accuracy: 0.6726
#
# Epoch 00019: val_loss did not improve from 0.76142
# Epoch 20/50
# 345/345 [==============================] - 90s 261ms/step - loss: 0.6124 - accuracy: 0.7647 - val_loss: 0.8453 - val_accuracy: 0.6686
#
# Epoch 00020: val_loss did not improve from 0.76142
# Epoch 21/50
# 345/345 [==============================] - 98s 284ms/step - loss: 0.6021 - accuracy: 0.7658 - val_loss: 0.9145 - val_accuracy: 0.6678
#
# Epoch 00021: val_loss did not improve from 0.76142
# Epoch 22/50
# 345/345 [==============================] - 88s 255ms/step - loss: 0.5984 - accuracy: 0.7704 - val_loss: 0.7658 - val_accuracy: 0.7093
#
# Epoch 00022: val_loss did not improve from 0.76142
# Epoch 23/50
# 345/345 [==============================] - 93s 269ms/step - loss: 0.5867 - accuracy: 0.7727 - val_loss: 0.7158 - val_accuracy: 0.7296
#
# Epoch 00023: val_loss improved from 0.76142 to 0.71581, saving model to FacialExpression_weights.hdf5
# Epoch 24/50
# 345/345 [==============================] - 90s 260ms/step - loss: 0.5732 - accuracy: 0.7820 - val_loss: 0.8602 - val_accuracy: 0.6580
#
# Epoch 00024: val_loss did not improve from 0.71581
# Epoch 25/50
# 345/345 [==============================] - 84s 243ms/step - loss: 0.5618 - accuracy: 0.7852 - val_loss: 0.7323 - val_accuracy: 0.7166
#
# Epoch 00025: val_loss did not improve from 0.71581
# Epoch 26/50
# 345/345 [==============================] - 90s 260ms/step - loss: 0.5449 - accuracy: 0.7904 - val_loss: 0.7561 - val_accuracy: 0.6979
#
# Epoch 00026: val_loss did not improve from 0.71581
# Epoch 27/50
# 345/345 [==============================] - 86s 250ms/step - loss: 0.5307 - accuracy: 0.7971 - val_loss: 0.8797 - val_accuracy: 0.6564
#
# Epoch 00027: val_loss did not improve from 0.71581
# Epoch 28/50
# 345/345 [==============================] - 86s 249ms/step - loss: 0.5430 - accuracy: 0.7891 - val_loss: 0.8027 - val_accuracy: 0.6963
#
# Epoch 00028: val_loss did not improve from 0.71581
# Epoch 29/50
# 345/345 [==============================] - 85s 246ms/step - loss: 0.5325 - accuracy: 0.7979 - val_loss: 0.9165 - val_accuracy: 0.6498
#
# Epoch 00029: val_loss did not improve from 0.71581
# Epoch 30/50
# 345/345 [==============================] - 87s 253ms/step - loss: 0.5072 - accuracy: 0.8047 - val_loss: 0.9686 - val_accuracy: 0.6490
#
# Epoch 00030: val_loss did not improve from 0.71581
# Epoch 31/50
# 345/345 [==============================] - 85s 246ms/step - loss: 0.5005 - accuracy: 0.8110 - val_loss: 0.7529 - val_accuracy: 0.7191
#
# Epoch 00031: val_loss did not improve from 0.71581
# Epoch 32/50
# 345/345 [==============================] - 85s 247ms/step - loss: 0.4857 - accuracy: 0.8138 - val_loss: 0.9838 - val_accuracy: 0.6621
#
# Epoch 00032: val_loss did not improve from 0.71581
# Epoch 33/50
# 345/345 [==============================] - 88s 255ms/step - loss: 0.4866 - accuracy: 0.8126 - val_loss: 0.7488 - val_accuracy: 0.7199
#
# Epoch 00033: val_loss did not improve from 0.71581
# Epoch 34/50
# 345/345 [==============================] - 89s 257ms/step - loss: 0.4758 - accuracy: 0.8187 - val_loss: 0.7844 - val_accuracy: 0.7044
#
# Epoch 00034: val_loss did not improve from 0.71581
# Epoch 35/50
# 345/345 [==============================] - 85s 246ms/step - loss: 0.4791 - accuracy: 0.8165 - val_loss: 0.7586 - val_accuracy: 0.7231
#
# Epoch 00035: val_loss did not improve from 0.71581
# Epoch 36/50
# 345/345 [==============================] - 86s 250ms/step - loss: 0.4709 - accuracy: 0.8231 - val_loss: 0.8090 - val_accuracy: 0.6686
#
# Epoch 00036: val_loss did not improve from 0.71581
# Epoch 37/50
# 345/345 [==============================] - 85s 246ms/step - loss: 0.4504 - accuracy: 0.8251 - val_loss: 0.7558 - val_accuracy: 0.7215
#
# Epoch 00037: val_loss did not improve from 0.71581
# Epoch 38/50
# 345/345 [==============================] - 85s 245ms/step - loss: 0.4401 - accuracy: 0.8345 - val_loss: 0.8398 - val_accuracy: 0.6686
#
# Epoch 00038: val_loss did not improve from 0.71581
# Epoch 39/50
# 345/345 [==============================] - 85s 246ms/step - loss: 0.4407 - accuracy: 0.8293 - val_loss: 0.7476 - val_accuracy: 0.7207
#
# Epoch 00039: val_loss did not improve from 0.71581
# Epoch 40/50
# 345/345 [==============================] - 84s 245ms/step - loss: 0.4345 - accuracy: 0.8316 - val_loss: 0.6748 - val_accuracy: 0.7590
#
# Epoch 00040: val_loss improved from 0.71581 to 0.67480, saving model to FacialExpression_weights.hdf5
# Epoch 41/50
# 345/345 [==============================] - 84s 244ms/step - loss: 0.4132 - accuracy: 0.8436 - val_loss: 0.7902 - val_accuracy: 0.7305
#
# Epoch 00041: val_loss did not improve from 0.67480
# Epoch 42/50
# 345/345 [==============================] - 85s 247ms/step - loss: 0.4117 - accuracy: 0.8468 - val_loss: 0.8391 - val_accuracy: 0.7003
#
# Epoch 00042: val_loss did not improve from 0.67480
# Epoch 43/50
# 345/345 [==============================] - 85s 247ms/step - loss: 0.4046 - accuracy: 0.8440 - val_loss: 0.7510 - val_accuracy: 0.7353
#
# Epoch 00043: val_loss did not improve from 0.67480
# Epoch 44/50
# 345/345 [==============================] - 87s 252ms/step - loss: 0.4033 - accuracy: 0.8448 - val_loss: 0.8019 - val_accuracy: 0.7199
#
# Epoch 00044: val_loss did not improve from 0.67480
# Epoch 45/50
# 345/345 [==============================] - 89s 257ms/step - loss: 0.3925 - accuracy: 0.8488 - val_loss: 0.7968 - val_accuracy: 0.7288
#
# Epoch 00045: val_loss did not improve from 0.67480
# Epoch 46/50
# 345/345 [==============================] - 75s 218ms/step - loss: 0.3982 - accuracy: 0.8488 - val_loss: 0.7515 - val_accuracy: 0.7272
#
# Epoch 00046: val_loss did not improve from 0.67480
# Epoch 47/50
# 345/345 [==============================] - 76s 220ms/step - loss: 0.3805 - accuracy: 0.8566 - val_loss: 2.6154 - val_accuracy: 0.4047
#
# Epoch 00047: val_loss did not improve from 0.67480
# Epoch 48/50
# 345/345 [==============================] - 76s 220ms/step - loss: 0.3817 - accuracy: 0.8547 - val_loss: 0.7441 - val_accuracy: 0.7223
#
# Epoch 00048: val_loss did not improve from 0.67480
# Epoch 49/50
# 345/345 [==============================] - 2553s 7s/step - loss: 0.3718 - accuracy: 0.8592 - val_loss: 0.9194 - val_accuracy: 0.6718
#
# Epoch 00049: val_loss did not improve from 0.67480
# Epoch 50/50
# 345/345 [==============================] - 67s 193ms/step - loss: 0.3656 - accuracy: 0.8566 - val_loss: 0.7618 - val_accuracy: 0.7248
#
# Epoch 00050: val_loss did not improve from 0.67480

# %%
# saving the model architecture to json file for future use

model_json = model_emotion.to_json()
with open("Emotion-model.json","w") as json_file:
  json_file.write(model_json)

# %% [markdown]
# # 7: ASSESS THE PERFORMANCE OF TRAINED FACIAL EXPRESSION CLASSIFIER MODEL

# %%
with open('Emotion-model.json', 'r') as json_file:
    json_savedModel= json_file.read()
    
# load the model architecture 
model_emotion = tf.keras.models.model_from_json(json_savedModel)
model_emotion.load_weights('FacialExpression_weights.hdf5')
model_emotion.compile(optimizer = "Adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
score = model_emotion.evaluate(X_Test, y_Test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 39/39 [==============================] - 1s 17ms/step - loss: 0.7300 - accuracy: 0.7649
# Test Accuracy: 0.7510170936584473

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
# predicted_classes = model.predict_classes(X_test)
predicted_classes = np.argmax(model_emotion.predict(X_Test), axis=-1)
y_true = np.argmax(y_Test, axis=-1)

# %%
y_true.shape
# Out:
# (1229,)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (10, 10))
sns.heatmap(cm, annot = True, cbar = False)
# Out:
# <AxesSubplot:>

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (24, 24))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_Test[i].reshape(48,48), cmap = 'gray')
    axes[i].set_title('Prediction = {}\n True = {}'.format(label_to_text[predicted_classes[i]], label_to_text[y_true[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.57      0.62       277
#            1       0.88      0.61      0.72        38
#            2       0.66      0.74      0.70       316
#            3       0.80      0.88      0.84       403
#            4       0.88      0.79      0.83       195
#
#     accuracy                           0.75      1229
#    macro avg       0.78      0.72      0.74      1229
# weighted avg       0.75      0.75      0.75      1229
